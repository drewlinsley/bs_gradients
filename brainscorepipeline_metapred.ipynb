# %%
models_meta = [
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "alexnet",
      "key": "IT_layer",
      "value": "features.12"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "alexnet",
      "key": "V1_layer",
      "value": "features.5"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "alexnet",
      "key": "V4_layer",
      "value": "features.7"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "alexnet",
      "key": "V2_layer",
      "value": "features.5"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "squeezenet1_0",
      "key": "IT_layer",
      "value": "features.12.expand3x3_activation"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "squeezenet1_0",
      "key": "V1_layer",
      "value": "features.7.expand3x3_activation"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "squeezenet1_0",
      "key": "V4_layer",
      "value": "features.7.expand3x3_activation"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "squeezenet1_0",
      "key": "V2_layer",
      "value": "features.7.expand3x3_activation"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "squeezenet1_1",
      "key": "IT_layer",
      "value": "features.9.expand3x3_activation"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "squeezenet1_1",
      "key": "V1_layer",
      "value": "features.9.expand3x3_activation"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "squeezenet1_1",
      "key": "V4_layer",
      "value": "features.6.expand3x3_activation"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "squeezenet1_1",
      "key": "V2_layer",
      "value": "features.9.expand3x3_activation"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-18",
      "key": "IT_layer",
      "value": "layer4.0.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-18",
      "key": "V1_layer",
      "value": "layer3.0.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-18",
      "key": "V4_layer",
      "value": "layer3.0.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-18",
      "key": "V2_layer",
      "value": "layer3.0.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-34",
      "key": "IT_layer",
      "value": "layer4.0.downsample.0"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-34",
      "key": "V1_layer",
      "value": "layer3.1.conv2"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-34",
      "key": "V4_layer",
      "value": "layer3.0.downsample.0"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-34",
      "key": "V2_layer",
      "value": "layer3.1.conv2"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "vgg-16",
      "key": "IT_layer",
      "value": "block4_pool"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "vgg-16",
      "key": "V1_layer",
      "value": "block3_pool"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "vgg-16",
      "key": "V4_layer",
      "value": "block3_pool"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "vgg-16",
      "key": "V2_layer",
      "value": "block4_pool"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "vgg-19",
      "key": "IT_layer",
      "value": "block4_pool"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "vgg-19",
      "key": "V1_layer",
      "value": "block3_pool"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "vgg-19",
      "key": "V4_layer",
      "value": "block3_pool"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "vgg-19",
      "key": "V2_layer",
      "value": "block4_pool"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "vggface",
      "key": "IT_layer",
      "value": "block4_pool"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "vggface",
      "key": "V1_layer",
      "value": "block3_pool"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "vggface",
      "key": "V4_layer",
      "value": "block3_pool"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "vggface",
      "key": "V2_layer",
      "value": "block3_pool"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "xception",
      "key": "IT_layer",
      "value": "block12_sepconv1_act"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "xception",
      "key": "V1_layer",
      "value": "block5_sepconv1_act"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "xception",
      "key": "V4_layer",
      "value": "block5_sepconv1_act"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "xception",
      "key": "V2_layer",
      "value": "block5_sepconv2_act"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "densenet-121",
      "key": "IT_layer",
      "value": "conv5_block15_concat"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "densenet-121",
      "key": "V1_layer",
      "value": "conv3_block11_concat"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "densenet-121",
      "key": "V4_layer",
      "value": "conv3_block5_concat"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "densenet-121",
      "key": "V2_layer",
      "value": "conv4_block2_concat"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "densenet-169",
      "key": "IT_layer",
      "value": "pool4_pool"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "densenet-169",
      "key": "V1_layer",
      "value": "conv3_block11_concat"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "densenet-169",
      "key": "V4_layer",
      "value": "conv3_block12_concat"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "densenet-169",
      "key": "V2_layer",
      "value": "conv4_block18_concat"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "densenet-201",
      "key": "IT_layer",
      "value": "pool4_pool"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "densenet-201",
      "key": "V1_layer",
      "value": "conv4_block27_concat"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "densenet-201",
      "key": "V4_layer",
      "value": "conv3_block1_concat"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "densenet-201",
      "key": "V2_layer",
      "value": "conv4_block33_concat"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "inception_v1",
      "key": "IT_layer",
      "value": "Mixed_4b"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "inception_v1",
      "key": "V1_layer",
      "value": "Mixed_3b"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "inception_v1",
      "key": "V4_layer",
      "value": "Mixed_3b"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "inception_v1",
      "key": "V2_layer",
      "value": "Mixed_4c"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "inception_v2",
      "key": "IT_layer",
      "value": "Mixed_5a"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "inception_v2",
      "key": "V1_layer",
      "value": "Mixed_3b"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "inception_v2",
      "key": "V4_layer",
      "value": "Mixed_4a"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "inception_v2",
      "key": "V2_layer",
      "value": "Mixed_4a"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "inception_v3",
      "key": "IT_layer",
      "value": "Mixed_7a"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "inception_v3",
      "key": "V1_layer",
      "value": "Mixed_6a"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "inception_v3",
      "key": "V4_layer",
      "value": "Mixed_5b"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "inception_v3",
      "key": "V2_layer",
      "value": "Mixed_6b"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "inception_v4",
      "key": "IT_layer",
      "value": "Mixed_6d"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "inception_v4",
      "key": "V1_layer",
      "value": "Mixed_5b"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "inception_v4",
      "key": "V4_layer",
      "value": "Mixed_5b"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "inception_v4",
      "key": "V2_layer",
      "value": "Mixed_5a"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "inception_resnet_v2",
      "key": "IT_layer",
      "value": "Mixed_7a"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "inception_resnet_v2",
      "key": "V1_layer",
      "value": "Mixed_6a"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "inception_resnet_v2",
      "key": "V4_layer",
      "value": "Mixed_6a"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "inception_resnet_v2",
      "key": "V2_layer",
      "value": "Mixed_6a"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-50_v1",
      "key": "IT_layer",
      "value": "resnet_v1_50/block4/unit_1/bottleneck_v1"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-50_v1",
      "key": "V1_layer",
      "value": "resnet_v1_50/block3/unit_1/bottleneck_v1"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-50_v1",
      "key": "V4_layer",
      "value": "resnet_v1_50/block2/unit_2/bottleneck_v1"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-50_v1",
      "key": "V2_layer",
      "value": "resnet_v1_50/block3/unit_6/bottleneck_v1"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-101_v1",
      "key": "IT_layer",
      "value": "resnet_v1_101/block3/unit_23/bottleneck_v1"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-101_v1",
      "key": "V1_layer",
      "value": "resnet_v1_101/block3/unit_5/bottleneck_v1"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-101_v1",
      "key": "V4_layer",
      "value": "resnet_v1_101/block3/unit_2/bottleneck_v1"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-101_v1",
      "key": "V2_layer",
      "value": "resnet_v1_101/block3/unit_9/bottleneck_v1"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-152_v1",
      "key": "IT_layer",
      "value": "resnet_v1_152/block3/unit_36/bottleneck_v1"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-152_v1",
      "key": "V1_layer",
      "value": "resnet_v1_152/block3/unit_1/bottleneck_v1"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-152_v1",
      "key": "V4_layer",
      "value": "resnet_v1_152/block3/unit_1/bottleneck_v1"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-152_v1",
      "key": "V2_layer",
      "value": "resnet_v1_152/block3/unit_12/bottleneck_v1"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-50_v2",
      "key": "IT_layer",
      "value": "resnet_v2_50/block4/unit_1/bottleneck_v2"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-50_v2",
      "key": "V1_layer",
      "value": "resnet_v2_50/block3/unit_2/bottleneck_v2"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-50_v2",
      "key": "V4_layer",
      "value": "resnet_v2_50/block3/unit_1/bottleneck_v2"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-50_v2",
      "key": "V2_layer",
      "value": "resnet_v2_50/block3/unit_6/bottleneck_v2"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-101_v2",
      "key": "IT_layer",
      "value": "resnet_v2_101/block4/unit_1/bottleneck_v2"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-101_v2",
      "key": "V1_layer",
      "value": "resnet_v2_101/block3/unit_17/bottleneck_v2"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-101_v2",
      "key": "V4_layer",
      "value": "resnet_v2_101/block3/unit_5/bottleneck_v2"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-101_v2",
      "key": "V2_layer",
      "value": "resnet_v2_101/block3/unit_21/bottleneck_v2"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-152_v2",
      "key": "IT_layer",
      "value": "resnet_v2_152/block4/unit_1/bottleneck_v2"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-152_v2",
      "key": "V1_layer",
      "value": "resnet_v2_152/block3/unit_32/bottleneck_v2"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-152_v2",
      "key": "V4_layer",
      "value": "resnet_v2_152/block3/unit_3/bottleneck_v2"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet-152_v2",
      "key": "V2_layer",
      "value": "resnet_v2_152/block3/unit_30/bottleneck_v2"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "nasnet_mobile",
      "key": "IT_layer",
      "value": "Reduction_Cell_1"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "nasnet_mobile",
      "key": "V1_layer",
      "value": "Cell_4"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "nasnet_mobile",
      "key": "V4_layer",
      "value": "Cell_4"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "nasnet_mobile",
      "key": "V2_layer",
      "value": "Cell_6"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "nasnet_large",
      "key": "IT_layer",
      "value": "Cell_12"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "nasnet_large",
      "key": "V1_layer",
      "value": "Cell_6"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "nasnet_large",
      "key": "V4_layer",
      "value": "Cell_1"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "nasnet_large",
      "key": "V2_layer",
      "value": "Cell_1"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "pnasnet_large",
      "key": "IT_layer",
      "value": "Cell_8"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "pnasnet_large",
      "key": "V1_layer",
      "value": "Cell_0"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "pnasnet_large",
      "key": "V4_layer",
      "value": "Cell_2"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "pnasnet_large",
      "key": "V2_layer",
      "value": "Cell_0"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "bagnet9",
      "key": "IT_layer",
      "value": "layer3.4.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "bagnet9",
      "key": "V1_layer",
      "value": "layer2.3.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "bagnet9",
      "key": "V4_layer",
      "value": "layer2.1.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "bagnet9",
      "key": "V2_layer",
      "value": "layer2.3.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "bagnet17",
      "key": "IT_layer",
      "value": "layer3.5.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "bagnet17",
      "key": "V1_layer",
      "value": "layer3.0.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "bagnet17",
      "key": "V4_layer",
      "value": "layer3.3.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "bagnet17",
      "key": "V2_layer",
      "value": "layer3.4.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "bagnet33",
      "key": "IT_layer",
      "value": "layer4.0.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "bagnet33",
      "key": "V1_layer",
      "value": "layer3.0.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "bagnet33",
      "key": "V4_layer",
      "value": "layer3.0.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "bagnet33",
      "key": "V2_layer",
      "value": "layer3.0.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet50-SIN",
      "key": "IT_layer",
      "value": "layer4.0.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet50-SIN",
      "key": "V1_layer",
      "value": "layer3.1.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet50-SIN",
      "key": "V4_layer",
      "value": "layer3.0.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet50-SIN",
      "key": "V2_layer",
      "value": "layer3.1.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet50-SIN_IN",
      "key": "IT_layer",
      "value": "layer4.0.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet50-SIN_IN",
      "key": "V1_layer",
      "value": "layer2.0.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet50-SIN_IN",
      "key": "V4_layer",
      "value": "layer2.3.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet50-SIN_IN",
      "key": "V2_layer",
      "value": "layer2.0.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet50-SIN_IN_IN",
      "key": "IT_layer",
      "value": "layer4.0.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet50-SIN_IN_IN",
      "key": "V1_layer",
      "value": "layer2.2.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet50-SIN_IN_IN",
      "key": "V4_layer",
      "value": "layer2.3.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnet50-SIN_IN_IN",
      "key": "V2_layer",
      "value": "layer3.3.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnext101_32x8d_wsl",
      "key": "IT_layer",
      "value": "layer3.3.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnext101_32x8d_wsl",
      "key": "V1_layer",
      "value": "layer2.0.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnext101_32x8d_wsl",
      "key": "V4_layer",
      "value": "layer2.1.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnext101_32x8d_wsl",
      "key": "V2_layer",
      "value": "layer1.2.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnext101_32x16d_wsl",
      "key": "IT_layer",
      "value": "layer3.20.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnext101_32x16d_wsl",
      "key": "V1_layer",
      "value": "layer2.0.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnext101_32x16d_wsl",
      "key": "V4_layer",
      "value": "layer2.1.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnext101_32x16d_wsl",
      "key": "V2_layer",
      "value": "layer1.2.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnext101_32x32d_wsl",
      "key": "IT_layer",
      "value": "layer3.21.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnext101_32x32d_wsl",
      "key": "V1_layer",
      "value": "layer1.0.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnext101_32x32d_wsl",
      "key": "V4_layer",
      "value": "layer2.0.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnext101_32x32d_wsl",
      "key": "V2_layer",
      "value": "layer3.2.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnext101_32x48d_wsl",
      "key": "IT_layer",
      "value": "layer3.20.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnext101_32x48d_wsl",
      "key": "V1_layer",
      "value": "layer1.0.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnext101_32x48d_wsl",
      "key": "V4_layer",
      "value": "layer2.0.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "resnext101_32x48d_wsl",
      "key": "V2_layer",
      "value": "layer3.4.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "fixres_resnext101_32x48d_wsl",
      "key": "IT_layer",
      "value": "layer3.20.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "fixres_resnext101_32x48d_wsl",
      "key": "V1_layer",
      "value": "layer3.1.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "fixres_resnext101_32x48d_wsl",
      "key": "V4_layer",
      "value": "layer2.0.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "fixres_resnext101_32x48d_wsl",
      "key": "V2_layer",
      "value": "layer1.1.relu"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_1.0_224",
      "key": "IT_layer",
      "value": "Conv2d_13_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_1.0_224",
      "key": "V1_layer",
      "value": "Conv2d_8_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_1.0_224",
      "key": "V4_layer",
      "value": "Conv2d_7_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_1.0_224",
      "key": "V2_layer",
      "value": "Conv2d_6_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_1.0_192",
      "key": "IT_layer",
      "value": "Conv2d_13_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_1.0_192",
      "key": "V1_layer",
      "value": "Conv2d_8_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_1.0_192",
      "key": "V4_layer",
      "value": "Conv2d_7_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_1.0_192",
      "key": "V2_layer",
      "value": "Conv2d_8_pointwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_1.0_160",
      "key": "IT_layer",
      "value": "Conv2d_12_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_1.0_160",
      "key": "V1_layer",
      "value": "Conv2d_8_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_1.0_160",
      "key": "V4_layer",
      "value": "Conv2d_4_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_1.0_160",
      "key": "V2_layer",
      "value": "Conv2d_6_pointwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_1.0_128",
      "key": "IT_layer",
      "value": "Conv2d_12_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_1.0_128",
      "key": "V1_layer",
      "value": "Conv2d_4_pointwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_1.0_128",
      "key": "V4_layer",
      "value": "Conv2d_5_pointwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_1.0_128",
      "key": "V2_layer",
      "value": "Conv2d_6_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.75_224",
      "key": "IT_layer",
      "value": "Conv2d_13_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.75_224",
      "key": "V1_layer",
      "value": "Conv2d_6_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.75_224",
      "key": "V4_layer",
      "value": "Conv2d_7_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.75_224",
      "key": "V2_layer",
      "value": "Conv2d_6_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.75_192",
      "key": "IT_layer",
      "value": "Conv2d_13_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.75_192",
      "key": "V1_layer",
      "value": "Conv2d_8_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.75_192",
      "key": "V4_layer",
      "value": "Conv2d_7_pointwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.75_192",
      "key": "V2_layer",
      "value": "Conv2d_6_pointwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.75_160",
      "key": "IT_layer",
      "value": "Conv2d_12_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.75_160",
      "key": "V1_layer",
      "value": "Conv2d_8_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.75_160",
      "key": "V4_layer",
      "value": "Conv2d_7_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.75_160",
      "key": "V2_layer",
      "value": "Conv2d_9_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.75_128",
      "key": "IT_layer",
      "value": "Conv2d_12_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.75_128",
      "key": "V1_layer",
      "value": "Conv2d_5_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.75_128",
      "key": "V4_layer",
      "value": "Conv2d_5_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.75_128",
      "key": "V2_layer",
      "value": "Conv2d_6_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.5_224",
      "key": "IT_layer",
      "value": "Conv2d_13_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.5_224",
      "key": "V1_layer",
      "value": "Conv2d_6_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.5_224",
      "key": "V4_layer",
      "value": "Conv2d_7_pointwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.5_224",
      "key": "V2_layer",
      "value": "Conv2d_6_pointwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.5_192",
      "key": "IT_layer",
      "value": "Conv2d_13_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.5_192",
      "key": "V1_layer",
      "value": "Conv2d_8_pointwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.5_192",
      "key": "V4_layer",
      "value": "Conv2d_7_pointwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.5_192",
      "key": "V2_layer",
      "value": "Conv2d_6_pointwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.5_160",
      "key": "IT_layer",
      "value": "Conv2d_12_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.5_160",
      "key": "V1_layer",
      "value": "Conv2d_8_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.5_160",
      "key": "V4_layer",
      "value": "Conv2d_5_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.5_160",
      "key": "V2_layer",
      "value": "Conv2d_8_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.5_128",
      "key": "IT_layer",
      "value": "Conv2d_12_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.5_128",
      "key": "V1_layer",
      "value": "Conv2d_8_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.5_128",
      "key": "V4_layer",
      "value": "Conv2d_5_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.5_128",
      "key": "V2_layer",
      "value": "Conv2d_8_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.25_224",
      "key": "IT_layer",
      "value": "Conv2d_13_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.25_224",
      "key": "V1_layer",
      "value": "Conv2d_7_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.25_224",
      "key": "V4_layer",
      "value": "Conv2d_7_pointwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.25_224",
      "key": "V2_layer",
      "value": "Conv2d_6_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.25_192",
      "key": "IT_layer",
      "value": "Conv2d_13_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.25_192",
      "key": "V1_layer",
      "value": "Conv2d_6_pointwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.25_192",
      "key": "V4_layer",
      "value": "Conv2d_8_pointwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.25_192",
      "key": "V2_layer",
      "value": "Conv2d_8_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.25_160",
      "key": "IT_layer",
      "value": "Conv2d_12_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.25_160",
      "key": "V1_layer",
      "value": "Conv2d_6_pointwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.25_160",
      "key": "V4_layer",
      "value": "Conv2d_7_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.25_160",
      "key": "V2_layer",
      "value": "Conv2d_6_pointwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.25_128",
      "key": "IT_layer",
      "value": "Conv2d_12_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.25_128",
      "key": "V1_layer",
      "value": "Conv2d_7_pointwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.25_128",
      "key": "V4_layer",
      "value": "Conv2d_5_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v1_0.25_128",
      "key": "V2_layer",
      "value": "Conv2d_7_depthwise"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.4_224",
      "key": "IT_layer",
      "value": "layer_15/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.4_224",
      "key": "V1_layer",
      "value": "layer_10/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.4_224",
      "key": "V4_layer",
      "value": "layer_9/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.4_224",
      "key": "V2_layer",
      "value": "layer_10/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.3_224",
      "key": "IT_layer",
      "value": "layer_15/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.3_224",
      "key": "V1_layer",
      "value": "layer_6/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.3_224",
      "key": "V4_layer",
      "value": "layer_9/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.3_224",
      "key": "V2_layer",
      "value": "layer_9/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.0_224",
      "key": "IT_layer",
      "value": "layer_15/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.0_224",
      "key": "V1_layer",
      "value": "layer_10/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.0_224",
      "key": "V4_layer",
      "value": "layer_9/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.0_224",
      "key": "V2_layer",
      "value": "layer_9/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.0_192",
      "key": "IT_layer",
      "value": "layer_15/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.0_192",
      "key": "V1_layer",
      "value": "layer_12/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.0_192",
      "key": "V4_layer",
      "value": "layer_9/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.0_192",
      "key": "V2_layer",
      "value": "layer_9/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.0_160",
      "key": "IT_layer",
      "value": "layer_15/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.0_160",
      "key": "V1_layer",
      "value": "layer_11/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.0_160",
      "key": "V4_layer",
      "value": "layer_5/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.0_160",
      "key": "V2_layer",
      "value": "layer_8/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.0_128",
      "key": "IT_layer",
      "value": "layer_15/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.0_128",
      "key": "V1_layer",
      "value": "layer_9/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.0_128",
      "key": "V4_layer",
      "value": "layer_7/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.0_128",
      "key": "V2_layer",
      "value": "layer_9/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.0_96",
      "key": "IT_layer",
      "value": "layer_15/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.0_96",
      "key": "V1_layer",
      "value": "layer_10/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.0_96",
      "key": "V4_layer",
      "value": "layer_6/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_1.0_96",
      "key": "V2_layer",
      "value": "layer_9/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.75_224",
      "key": "IT_layer",
      "value": "layer_15/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.75_224",
      "key": "V1_layer",
      "value": "layer_10/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.75_224",
      "key": "V4_layer",
      "value": "layer_9/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.75_224",
      "key": "V2_layer",
      "value": "layer_9/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.75_192",
      "key": "IT_layer",
      "value": "layer_15/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.75_192",
      "key": "V1_layer",
      "value": "layer_11/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.75_192",
      "key": "V4_layer",
      "value": "layer_5/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.75_192",
      "key": "V2_layer",
      "value": "layer_11/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.75_160",
      "key": "IT_layer",
      "value": "layer_15/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.75_160",
      "key": "V1_layer",
      "value": "layer_10/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.75_160",
      "key": "V4_layer",
      "value": "layer_6/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.75_160",
      "key": "V2_layer",
      "value": "layer_8/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.75_128",
      "key": "IT_layer",
      "value": "layer_15/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.75_128",
      "key": "V1_layer",
      "value": "layer_5/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.75_128",
      "key": "V4_layer",
      "value": "layer_5/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.75_128",
      "key": "V2_layer",
      "value": "layer_11/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.75_96",
      "key": "IT_layer",
      "value": "layer_15/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.75_96",
      "key": "V1_layer",
      "value": "layer_5/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.75_96",
      "key": "V4_layer",
      "value": "layer_7/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.75_96",
      "key": "V2_layer",
      "value": "layer_11/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.5_224",
      "key": "IT_layer",
      "value": "layer_15/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.5_224",
      "key": "V1_layer",
      "value": "layer_9/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.5_224",
      "key": "V4_layer",
      "value": "layer_8/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.5_224",
      "key": "V2_layer",
      "value": "layer_11/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.5_192",
      "key": "IT_layer",
      "value": "layer_15/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.5_192",
      "key": "V1_layer",
      "value": "layer_8/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.5_192",
      "key": "V4_layer",
      "value": "layer_6/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.5_192",
      "key": "V2_layer",
      "value": "layer_9/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.5_160",
      "key": "IT_layer",
      "value": "layer_15/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.5_160",
      "key": "V1_layer",
      "value": "layer_11/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.5_160",
      "key": "V4_layer",
      "value": "layer_5/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.5_160",
      "key": "V2_layer",
      "value": "layer_8/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.5_128",
      "key": "IT_layer",
      "value": "layer_15/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.5_128",
      "key": "V1_layer",
      "value": "layer_8/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.5_128",
      "key": "V4_layer",
      "value": "layer_6/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.5_128",
      "key": "V2_layer",
      "value": "layer_9/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.5_96",
      "key": "IT_layer",
      "value": "layer_15/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.5_96",
      "key": "V1_layer",
      "value": "layer_10/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.5_96",
      "key": "V4_layer",
      "value": "layer_7/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.5_96",
      "key": "V2_layer",
      "value": "layer_9/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.35_224",
      "key": "IT_layer",
      "value": "layer_15/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.35_224",
      "key": "V1_layer",
      "value": "layer_9/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.35_224",
      "key": "V4_layer",
      "value": "layer_9/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.35_224",
      "key": "V2_layer",
      "value": "layer_9/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.35_192",
      "key": "IT_layer",
      "value": "layer_15/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.35_192",
      "key": "V1_layer",
      "value": "layer_9/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.35_192",
      "key": "V4_layer",
      "value": "layer_8/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.35_192",
      "key": "V2_layer",
      "value": "layer_11/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.35_160",
      "key": "IT_layer",
      "value": "layer_15/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.35_160",
      "key": "V1_layer",
      "value": "layer_8/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.35_160",
      "key": "V4_layer",
      "value": "layer_9/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.35_160",
      "key": "V2_layer",
      "value": "layer_9/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.35_128",
      "key": "IT_layer",
      "value": "layer_15/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.35_128",
      "key": "V1_layer",
      "value": "layer_8/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.35_128",
      "key": "V4_layer",
      "value": "layer_6/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.35_128",
      "key": "V2_layer",
      "value": "layer_11/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.35_96",
      "key": "IT_layer",
      "value": "layer_15/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.35_96",
      "key": "V1_layer",
      "value": "layer_8/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.35_96",
      "key": "V4_layer",
      "value": "layer_6/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "mobilenet_v2_0.35_96",
      "key": "V2_layer",
      "value": "layer_9/output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "CORnet-Z",
      "key": "IT_layer",
      "value": "IT.output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "CORnet-Z",
      "key": "V1_layer",
      "value": "V1.output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "CORnet-Z",
      "key": "V4_layer",
      "value": "V4.output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "CORnet-Z",
      "key": "V2_layer",
      "value": "V2.output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "CORnet-S",
      "key": "IT_layer",
      "value": "IT.output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "CORnet-S",
      "key": "V1_layer",
      "value": "V1.output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "CORnet-S",
      "key": "V4_layer",
      "value": "V4.output"
    }
  },
  {
    "model": "benchmarks.ModelMeta",
    "fields": {
      "model": "CORnet-S",
      "key": "V2_layer",
      "value": "V2.output"
    }
  }
]

# %%
meta={}
for s in models_meta : 
  if s['fields']['model'] not in meta: 
    meta[s['fields']['model']]={s['fields']['key']:s['fields']['value']}
  else: 
    meta[s['fields']['model']][s['fields']['key']]=s['fields']['value']

# %%
# !pip uninstall keras -y
# Out:
# Found existing installation: keras 2.9.0
# Uninstalling keras-2.9.0:
#   Successfully uninstalled keras-2.9.0

# %%
#import cv2
import numpy as np
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
from sklearn.cross_decomposition import PLSRegression
from sklearn.model_selection import train_test_split
import cv2
import tensorflow as tf
from tensorflow.keras.layers import *
import brainscore

def set_size(w,h):
  plt.rcParams["figure.figsize"] = [w,h]

def show(img, p=False, **kwargs):
  """manages to display an image"""
  img = np.array(img, dtype=np.float32)
  # check if channel first
  if img.shape[0] == 1:
    img = img[0]
  elif img.shape[0] == 3:
    img = np.moveaxis(img, 0, 2)
  # check if cmap
  if img.shape[-1] == 1:
    img = img[:,:,0]
  # normalize
  if img.max() > 1 or img.min() < 0:
    img -= img.min(); img/=img.max()

  plt.imshow(img, **kwargs)
  plt.axis('off')
  plt.grid(None)
# Out:
# Loading lookup from /gpfs/data/tserre/irodri15/Brainscore/venv_bs/lib/python3.6/site-packages/brainio_collection-0.1.0-py3.6.egg/brainio_collection/lookup.csv
# /gpfs/data/tserre/irodri15/Brainscore/original_repos/brain-score/brainscore/metrics/__init__.py:37: FutureWarning: xarray subclass Score should explicitly define __slots__
#   class Score(DataAssembly):

# %%
from brainscore.benchmarks.public_benchmarks import MajajHongITPublicBenchmark

size = 224



benchmark = MajajHongITPublicBenchmark()

def load_ids(ids):
  images_paths = [benchmark._assembly.stimulus_set.get_image(img_id) for img_id in ids]
  images = np.array([cv2.imread(p) for p in images_paths])
  images = tf.image.resize(images, (size, size)).numpy()
  return images

# %%
batch_size = 64

def batch_predict(model, inputs, batch_size=batch_size):
  activations = []
  
  for batch_x in tf.data.Dataset.from_tensor_slices(inputs).batch(batch_size):
    #print('here')
    batch_act = model(batch_x)
    batch_act = np.array(batch_act, np.float16)
    activations += list(batch_act)

  return np.array(activations, np.float16)

def tf_pearson_loss(x, y, axis=-1):
  """
  Compute the Pearson's correlation as the centered cosine similarity
  """
  x_means = tf.reduce_mean(x, axis, keepdims=True)
  y_means = tf.reduce_mean(y, axis, keepdims=True)

  x_centered = x - x_means
  y_centered = y - y_means

  inner_products = tf.reduce_sum(x_centered * y_centered, axis)
  norms = tf.sqrt(tf.reduce_sum(x_centered**2, axis)) * \
         tf.sqrt(tf.reduce_sum(y_centered**2, axis))

  correlations = inner_products / norms
  
  return correlations

def brain_score(activation_model, X_train, Y_train, X_test, Y_test):
  A_train = batch_predict(activation_model, X_train, batch_size)
  A_train = A_train.reshape((len(X_train), -1))

  pls_reg = PLSRegression(20, scale=False, tol=1e-4)
  pls_reg.fit(A_train, Y_train)

  pls_kernel = tf.cast(pls_reg.coef_, tf.float16)
  Y_test = tf.cast(Y_test, tf.float16)

  A_test = batch_predict(activation_model, X_test, batch_size)
  A_test = A_test.reshape((len(X_test), -1))

  Y_pred = tf.matmul(A_test, pls_kernel)

  correlations = tf_pearson_loss(
      tf.transpose(Y_pred),
      tf.transpose(Y_test)
  )

  score = np.mean(correlations)
  print(score)

  return score, pls_kernel

# %%
import cv2
from tensorflow.keras.applications import *
import inspect
import re
def matching_strings(pattern, text): 
    left = 0
    count = 0
    while True:
        match = re.search(pattern, text[left:])
        if not match:
            break
        count += 1
        left += match.start() + 1
   
    return count

# %%
_mean_imagenet = tf.constant([0.485, 0.456, 0.406], shape=[1, 1, 3], dtype=tf.float32)
_std_imagenet =  tf.constant([0.229, 0.224, 0.225], shape=[1, 1, 3], dtype=tf.float32)
def preprocess(x):
    x = x/255.
    x -= _mean_imagenet
    x /= _std_imagenet
    return x

# %%
train_ids, test_ids = np.load('data/train_ids.npy', allow_pickle=True), np.load('data/test_ids.npy', allow_pickle=True)
all_ids = np.array(list(train_ids)+list(test_ids))
X_all = load_ids(all_ids)

Y_train, Y_test = np.load('data/y_train.npy'), np.load('data/y_test.npy')
X_train, X_test = load_ids(train_ids), load_ids(test_ids)

# %%
X_all = np.concatenate([X_train,X_test],axis=0)
Y_all = np.concatenate([Y_train,Y_test],axis=0)

# %%
X_all = np.array([ preprocess(x) for x in X_all])

# %%
import glob 

models =glob.glob('/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/*h5')

# %%
models
# Out:
# ['/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/gradcam_resilient_snowball.h5',
#  '/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/gradcam_etheral_cosmos.h5',
#  '/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/saliency_good_night.h5',
#  '/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/saliency_dulcet_wildflower.h5',
#  '/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_frosty_eon.h5',
#  '/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/saliency_fallen_water.h5',
#  '/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_silver_moon.h5',
#  '/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/gradcam_breezy_music.h5',
#  '/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/gradcam_magic_serenity.h5',
#  '/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/saliency_volcanic_monkey.h5',
#  '/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/saliency_glad_dawn.h5',
#  '/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/saliency_rare_galaxy.h5',
#  '/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/gradcam_vibrant_night.h5',
#  '/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_baseline.h5',
#  '/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/resnet50_baseline.h5',
#  '/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/gradcam_stilted_plasma.h5',
#  '/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/saliency_radiant_microwave.h5',
#  '/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/saliency_sunny_plant.h5']

# %%
models =['/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_baseline.h5',
          '/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_frosty_eon.h5',
 '/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/resnet50_baseline.h5',
         '/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/saliency_volcanic_monkey.h5',
 '/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_silver_moon.h5',
         ]

# %%
#!pip install tensorflow==2.6

# %%
model = tf.keras.models.load_model('/cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_baseline.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
model.layers[0].name
# Out:
# 'input_1'

# %%
from sklearn.model_selection import train_test_split
results = {}
for MODEL_NAME in models:
    print(MODEL_NAME)
    model = tf.keras.models.load_model(MODEL_NAME)
    if 'vgg' in MODEL_NAME: 
        k = 'vgg-16'
    else:
        k = 'resnet-50_v2'
    for layer_type in model.layers[-6:]:
        print(layer_type)
        scores = []
        for _ in range(2):
            layer = layer_type.name
            activation_model = tf.keras.Model(model.input, model.get_layer(layer).output)
            #A = batch_predict(activation_model, X_all, batch_size)
            #A = A.reshape((len(X_all), -1))
            x_train,  x_test,y_train, y_test = train_test_split(X_all,Y_all,test_size=0.1)
            score,_ = brain_score(activation_model, x_train, y_train, x_test, y_test)
            scores.append(score)
        mean_score = np.mean(scores) 
        print(MODEL_NAME)
        print(k) 
        print(mean_score)
        if k not in results:
            results[k] = {}
        results[k][layer] = mean_score
# Out:
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_baseline.h5
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3e38a91358>
# 0.585
# 0.568
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_baseline.h5
# vgg-16
# 0.576
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f3e30de92e8>
# 0.563
# 0.5596
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_baseline.h5
# vgg-16
# 0.5615
# <tensorflow.python.keras.layers.core.Flatten object at 0x7f3e30de9588>
# 0.5723
# 0.572
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_baseline.h5
# vgg-16
# 0.5723
# <tensorflow.python.keras.layers.core.Dense object at 0x7f3e30de9748>
# 0.538
# 0.533
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_baseline.h5
# vgg-16
# 0.5356
# <tensorflow.python.keras.layers.core.Dense object at 0x7f3e30de9a90>
# 0.525
# 0.533
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_baseline.h5
# vgg-16
# 0.5293
# <tensorflow.python.keras.layers.core.Dense object at 0x7f3e30de9dd8>
# 0.5137
# 0.5063
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_baseline.h5
# vgg-16
# 0.51
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_frosty_eon.h5
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3e38f74f60>
# 0.57
# 0.582
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_frosty_eon.h5
# vgg-16
# 0.576
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f3e38f80518>
# 0.5693
# 0.586
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_frosty_eon.h5
# vgg-16
# 0.5776
# <tensorflow.python.keras.layers.core.Flatten object at 0x7f3e38f807b8>
# 0.577
# 0.5845
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_frosty_eon.h5
# vgg-16
# 0.581
# <tensorflow.python.keras.layers.core.Dense object at 0x7f3e38f80978>
# 0.5493
# 0.5293
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_frosty_eon.h5
# vgg-16
# 0.539
# <tensorflow.python.keras.layers.core.Dense object at 0x7f3e38f80cc0>
# 0.5225
# 0.5327
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_frosty_eon.h5
# vgg-16
# 0.5273
# <tensorflow.python.keras.layers.core.Dense object at 0x7f3e38f8b048>
# 0.5195
# 0.4988
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_frosty_eon.h5
# vgg-16
# 0.5093
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/resnet50_baseline.h5
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3e31018d68>
# 0.527
# 0.515
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/resnet50_baseline.h5
# resnet-50_v2
# 0.521
# <tensorflow.python.keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f3e30f65320>
# 0.529
# 0.515
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/resnet50_baseline.h5
# resnet-50_v2
# 0.522
# <tensorflow.python.keras.layers.merge.Add object at 0x7f3e30f657b8>
# 0.546
# 0.54
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/resnet50_baseline.h5
# resnet-50_v2
# 0.543
# <tensorflow.python.keras.layers.core.Activation object at 0x7f3e30f65860>
# 0.561
# 0.526
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/resnet50_baseline.h5
# resnet-50_v2
# 0.5435
# <tensorflow.python.keras.layers.pooling.GlobalAveragePooling2D object at 0x7f3e30f65a20>
# 0.507
# 0.4988
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/resnet50_baseline.h5
# resnet-50_v2
# 0.503
# <tensorflow.python.keras.layers.core.Dense object at 0x7f3e30f65be0>
# 0.4617
# 0.4753
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/resnet50_baseline.h5
# resnet-50_v2
# 0.4685
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/saliency_volcanic_monkey.h5
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3e30c3d4a8>
# 0.2585
# 0.2568
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/saliency_volcanic_monkey.h5
# resnet-50_v2
# 0.2578
# <tensorflow.python.keras.layers.normalization.batch_normalization.BatchNormalization object at 0x7f3e30c3da20>
# 0.259
# 0.2603
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/saliency_volcanic_monkey.h5
# resnet-50_v2
# 0.2598
# <tensorflow.python.keras.layers.merge.Add object at 0x7f3e30c3deb8>
# 0.5303
# 0.542
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/saliency_volcanic_monkey.h5
# resnet-50_v2
# 0.536
# <tensorflow.python.keras.layers.core.Activation object at 0x7f3e30c3df60>
# 0.5513
# 0.549
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/saliency_volcanic_monkey.h5
# resnet-50_v2
# 0.55
# <tensorflow.python.keras.layers.pooling.GlobalAveragePooling2D object at 0x7f3e30c4b160>
# 0.5176
# 0.5015
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/saliency_volcanic_monkey.h5
# resnet-50_v2
# 0.51
# <tensorflow.python.keras.layers.core.Dense object at 0x7f3e30c4b320>
# 0.4644
# 0.4832
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/saliency_volcanic_monkey.h5
# resnet-50_v2
# 0.4736
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_silver_moon.h5
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f3e38d75e10>
# 0.582
# 0.5757
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_silver_moon.h5
# vgg-16
# 0.579
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f3e38e42668>
# 0.579
# 0.56
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_silver_moon.h5
# vgg-16
# 0.5693
# <tensorflow.python.keras.layers.core.Flatten object at 0x7f3e38efeb38>
# 0.5747
# 0.567
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_silver_moon.h5
# vgg-16
# 0.571
# <tensorflow.python.keras.layers.core.Dense object at 0x7f3e38efeb00>
# 0.546
# 0.5405
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_silver_moon.h5
# vgg-16
# 0.543
# <tensorflow.python.keras.layers.core.Dense object at 0x7f3e38f97588>
# 0.5195
# 0.5083
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_silver_moon.h5
# vgg-16
# 0.5137
# <tensorflow.python.keras.layers.core.Dense object at 0x7f3e38f97b00>
# 0.5063
# 0.5
# /cifs/data/tserre_lrs/projects/prj_metapredictor/meta_models/models/vgg_silver_moon.h5
# vgg-16
# 0.503

# %%
meta['vgg-16'].keys()
# Out:
# dict_keys(['IT_layer', 'V1_layer', 'V4_layer', 'V2_layer'])

# %%
results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-100f62972f2f> in <module>
# ----> 1 results
#
# NameError: name 'results' is not defined

# %%
meta.keys()
# Out:
# dict_keys(['alexnet', 'squeezenet1_0', 'squeezenet1_1', 'resnet-18', 'resnet-34', 'vgg-16', 'vgg-19', 'vggface', 'xception', 'densenet-121', 'densenet-169', 'densenet-201', 'inception_v1', 'inception_v2', 'inception_v3', 'inception_v4', 'inception_resnet_v2', 'resnet-50_v1', 'resnet-101_v1', 'resnet-152_v1', 'resnet-50_v2', 'resnet-101_v2', 'resnet-152_v2', 'nasnet_mobile', 'nasnet_large', 'pnasnet_large', 'bagnet9', 'bagnet17', 'bagnet33', 'resnet50-SIN', 'resnet50-SIN_IN', 'resnet50-SIN_IN_IN', 'resnext101_32x8d_wsl', 'resnext101_32x16d_wsl', 'resnext101_32x32d_wsl', 'resnext101_32x48d_wsl', 'fixres_resnext101_32x48d_wsl', 'mobilenet_v1_1.0_224', 'mobilenet_v1_1.0_192', 'mobilenet_v1_1.0_160', 'mobilenet_v1_1.0_128', 'mobilenet_v1_0.75_224', 'mobilenet_v1_0.75_192', 'mobilenet_v1_0.75_160', 'mobilenet_v1_0.75_128', 'mobilenet_v1_0.5_224', 'mobilenet_v1_0.5_192', 'mobilenet_v1_0.5_160', 'mobilenet_v1_0.5_128', 'mobilenet_v1_0.25_224', 'mobilenet_v1_0.25_192', 'mobilenet_v1_0.25_160', 'mobilenet_v1_0.25_128', 'mobilenet_v2_1.4_224', 'mobilenet_v2_1.3_224', 'mobilenet_v2_1.0_224', 'mobilenet_v2_1.0_192', 'mobilenet_v2_1.0_160', 'mobilenet_v2_1.0_128', 'mobilenet_v2_1.0_96', 'mobilenet_v2_0.75_224', 'mobilenet_v2_0.75_192', 'mobilenet_v2_0.75_160', 'mobilenet_v2_0.75_128', 'mobilenet_v2_0.75_96', 'mobilenet_v2_0.5_224', 'mobilenet_v2_0.5_192', 'mobilenet_v2_0.5_160', 'mobilenet_v2_0.5_128', 'mobilenet_v2_0.5_96', 'mobilenet_v2_0.35_224', 'mobilenet_v2_0.35_192', 'mobilenet_v2_0.35_160', 'mobilenet_v2_0.35_128', 'mobilenet_v2_0.35_96', 'CORnet-Z', 'CORnet-S'])

# %%
preprocess = tf.keras.applications.vgg16.preprocess_input
X_train_preprocessed = np.array(preprocess(np.array(X_train, copy=True)), np.float16)
X_test_preprocess = np.array(preprocess(np.array(X_test, copy=True)), np.float16)

# %%
keras_models= inspect.getmembers(tf.keras.applications)

for km in keras_models:
    if type(km[1])== type(tf.keras.applications.resnet_v2.ResNet50V2):
        pattern = km[0].lower()
        text = []
        for k in meta.keys():
            count = matching_strings(pattern,k.replace('-',''))
            if count>0:
                print(pattern, k.replace('-',''), count)
                for layer_type in meta[k]: 
                    layer = meta[k][layer_type]
                    #print(f'data/{k}_{layer_type}_{layer}_features.npy')
                    model = km[1].__call__()
                    model.summary()
                    try:
                        activation_model = tf.keras.Model(model.input, model.get_layer(layer).output)
                    except: 
                        print('not layer like that')
                        continue
                    A = batch_predict(activation_model, X_all, batch_size)
                    A = A.reshape((len(X_all), -1))
                    print(f'data/{k}_{layer_type}_{layer}_features.npy')
                    score,_,correlations = brain_score(activation_model, X_train, Y_train, X_test, Y_test)

# %%
np.save(f'data/all_ids.npy',all_ids)
np.save(f'data/all_imgs.npy',X_all)
np.save(f'data/all_neuids.npy',all_neuralids)

# %%
all_neuralids = np.concatenate((Y_test,Y_train))

# %%
# !cp data/*all* data/BSHK_task2_data/

# %%
model = tf.keras.applications.vgg16.VGG16()
preprocess = tf.keras.applications.vgg16.preprocess_input

# %%
layer = 'block4_pool'
activation_model = tf.keras.Model(model.input, model.get_layer(layer).output)
A_train = batch_predict(activation_model, X_train, batch_size)
A_train = A_train.reshape((len(X_train), -1))

# %%
A_train = A_train.reshape((len(X_train), -1))

# %%
A_train
# Out:
# (2880, 100352)
